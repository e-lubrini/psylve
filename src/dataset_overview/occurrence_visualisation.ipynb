# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
## substitute string with key column to identify each document
key_id = ''

# %%
## open data file
with open(os.path.join('occurrence_data.csv'), 'r') as f:
    df = pd.read_csv(f)

# %%
## treat data in listed column(s) as numeric
numeric_columns = ['dateIdentified'] 
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df.head()
# Out:
#   catalogNumber      phylum    class      order        suborder superfamily  \
# 0        NS0001  Arthropoda  Insecta  Hemiptera  Sternorrhyncha  Psylloidea
# 1        NS0002  Arthropoda  Insecta  Hemiptera  Sternorrhyncha  Psylloidea
# 2        NS0003  Arthropoda  Insecta  Hemiptera  Sternorrhyncha  Psylloidea
# 3        NS0004  Arthropoda  Insecta  Hemiptera  Sternorrhyncha  Psylloidea
# 4        NS0005  Arthropoda  Insecta  Hemiptera  Sternorrhyncha  Psylloidea
#
#                       family                  subfamily  \
# 0  Psyllidae Latreille, 1807  Psyllinae Latreille, 1807
# 1  Psyllidae Latreille, 1807  Psyllinae Latreille, 1807
# 2  Psyllidae Latreille, 1807  Psyllinae Latreille, 1807
# 3  Psyllidae Latreille, 1807  Psyllinae Latreille, 1807
# 4  Psyllidae Latreille, 1807  Psyllinae Latreille, 1807
#
#                             genus  \
# 0  Cacopsylla Ossiannilsson, 1970
# 1  Cacopsylla Ossiannilsson, 1970
# 2  Cacopsylla Ossiannilsson, 1970
# 3  Cacopsylla Ossiannilsson, 1970
# 4  Cacopsylla Ossiannilsson, 1970
#
#                                  acceptedNameUsage  ...   hostPlantLatinName  \
# 0  Cacopsylla (Thamnopsylla) pruni (Scopoli, 1763)  ...  unspecified species
# 1  Cacopsylla (Thamnopsylla) pruni (Scopoli, 1763)  ...  unspecified species
# 2  Cacopsylla (Thamnopsylla) pruni (Scopoli, 1763)  ...  unspecified species
# 3  Cacopsylla (Thamnopsylla) pruni (Scopoli, 1763)  ...  unspecified species
# 4  Cacopsylla (Thamnopsylla) pruni (Scopoli, 1763)  ...  unspecified species
#
#   hostPlantVernacularName sourceCategory ownerInstitutionCode  \
# 0                     NaN     Literature                  NaN
# 1                     NaN     Literature                  NaN
# 2                     NaN     Literature                  NaN
# 3                     NaN     Literature                  NaN
# 4                     NaN     Literature                  NaN
#
#                                  locationAccordingTo dateIdentified page  \
# 0  Steffek R, Swen Follak S, Sauvion N, Labonne G...         2012.0  198
# 1  Malenovsky I, Lauterer P, Labina E & Burckhard...         2012.0  NaN
# 2  Steffek R, Swen Follak S, Sauvion N, Labonne G...         2012.0  198
# 3  Klimaszewski SM (1961) Psyllidologische Notize...         1961.0  NaN
# 4  Steffek R, Swen Follak S, Sauvion N, Labonne G...         2012.0  198
#
#    eventDate  eventDate.1                               associatedReferences
# 0       2012         2012  https://onlinelibrary.wiley.com/doi/abs/10.111...
# 1        NaN          NaN  http://swfrec.ifas.ufl.edu/hlb/database/pdf/00...
# 2       2012         2012  https://onlinelibrary.wiley.com/doi/abs/10.111...
# 3        NaN          NaN                                                NaN
# 4       2012         2012  https://onlinelibrary.wiley.com/doi/abs/10.111...
#
# [5 rows x 31 columns]

# %%
from tools.visual import plot
# TODO associated database associatedreference
save_dir = os.path.join(os.getcwd(), 'imgs')

# %%
x = 'dateIdentified'
y = 'sourceCategory'
hue = 'sourceCategory'
palette = sns.color_palette('tab10',n_colors=2)

plot(x=x, y=y,
    hue=hue, data=df,
    type='violin',
    #split={hue:2},
    drop_na=[x],
    xlabel='date', ylabel='sourceCategory',
    huelabel='source',
    sort_alpha=[hue],
    swarm=True,
    #vlines=[
    #    {'x':1950,'ymin':0,'ymax':1,'gid':'copyright', 'c':palette[1]},
    #    {'x':2020,'ymin':0,'ymax':1,'gid':'last publication', 'c':'black'}
    #    ],
    save_dir = save_dir,
    )
# Out:
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 81.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
x = 'dateIdentified'
y = 'sourceCategory'
hue = 'sourceCategory'
style= 'sourceCategory'

plot(x=x, y=y, hue=hue, style=style, data=df,
    type='scatter',
    #split={hue:4,style:3,y:7}, #slice_top={y:5},
    legend_position='out',
    xlabel='date', ylabel='database',
    sort_alpha=[hue],
    save_dir = save_dir,
    )

# %%
x = 'dateIdentified'
hue = 'PDF'
y = 'language'
palette = sns.color_palette('tab10',n_colors=10)

plot(x=x, y=y, hue=hue, data=df,
    type='violin',
    legend_position='lower left',
    slice_top={y:3},
    drop_doubles=[key_id], drop_na=[x],
    xlabel='date', ylabel='language', huelabel='pdf availability',
    #vlines=[
    #    {'x':1950,'ymin':0,'ymax':1,'gid':'copyright', 'c':palette[3]},
    #    {'x':2020,'ymin':0,'ymax':1,'gid':'last publication', 'c':'black'}
    #    ],
    swarm=True,
    save_dir = save_dir,
    )
# German: copyright from 1950
# English: a lot of info in unvailable documents
# Out:
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 16.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
x = 'dateIdentified'
hue = 'availability'
y = 'language'

plot(x=x, y=y, hue=hue, data=df,
    type='violin',
    legend_position='lower left',
    split={hue:2,y:2}, 
    xlabel='date', ylabel='language', huelabel='online availability',
    save_dir = save_dir,
    )
