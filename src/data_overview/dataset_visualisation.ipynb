# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tools.visual import plot
# Out:
#   Input In [4]
#     from ... import tools.visual.plot
#                          ^
# SyntaxError: invalid syntax

# %%
## substitute string with key column to identify each document
key_id = 'locationAccordingTo'

# %%
## open data file
with open(os.path.join('dataset_metadata.csv'), 'r') as f:
    df = pd.read_csv(f)
    
## treat data in listed column(s) as numeric
numeric_columns = ['dateIdentified'] 
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df.head()
# Out:
#   catalogNumber sourceCategory  dateIdentified     database language  \
# 0        NS0897     Literature          1895.0  archive.org   German
# 1        NS1364     Literature          1955.0          BHL  Chinese
# 2        NS1365     Literature          1955.0          BHL  Chinese
# 3        NS1366     Literature          1955.0          BHL  Chinese
# 4        NS1122     Literature          1837.0          BHL  English
#
#   availability  PDF                          Corpus_PDF_references  \
# 0  free_online  PDF                   1895_Henchel_review_psyllids
# 1  free_online  PDF  1955_Pavlovsky_Cacopsylla_pruni_CCCP_Irkurskt
# 2  free_online  PDF  1955_Pavlovsky_Cacopsylla_pruni_CCCP_Irkurskt
# 3  free_online  PDF  1955_Pavlovsky_Cacopsylla_pruni_CCCP_Irkurskt
# 4  free_online  PDF  1837_Curtis_Cacopsylla_pruni_Britain_page_220
#
#     References Endnote                               associatedReferences  \
# 0    Henchel GA (1895)  https://ia600305.us.archive.org/2/items/bub_gb...
# 1  Pavlovsky EN (1955)  https://www.biodiversitylibrary.org/page/36567904
# 2  Pavlovsky EN (1955)  https://www.biodiversitylibrary.org/page/36567904
# 3  Pavlovsky EN (1955)  https://www.biodiversitylibrary.org/page/36567904
# 4      Curtis J (1837)            https://doi.org/10.5962/bhl.title.46860
#
#                                  locationAccordingTo
# 0  Henchel GA (1895) Die Schadlichen Forst- Und O...
# 1  Pavlovsky EN (1955) Forest Pest Reference II. ...
# 2  Pavlovsky EN (1955) Forest Pest Reference II. ...
# 3  Pavlovsky EN (1955) Forest Pest Reference II. ...
# 4  Curtis J (1837) A guide to an arrangement of B...

# %%
# TODO associated database associatedreference
save_dir = os.path.join(os.getcwd(),'..','..','data','imgs','data_overview')

# %%
x = 'dateIdentified'
y = 'availability'
hue = 'language'
palette = sns.color_palette('tab10',n_colors=2)

plot(x=x, y=y, hue=hue, data=df,
    type='violin',
    split={hue:2},
    drop_doubles=[key_id], drop_na=[x],
    xlabel='date', ylabel='accessibility', huelabel='language',
    sort_alpha=[hue],
    swarm=True,
    #vlines=[
    #    {'x':1950,'ymin':0,'ymax':1,'gid':'copyright', 'c':palette[1]},
    #    {'x':2020,'ymin':0,'ymax':1,'gid':'last publication', 'c':'black'}
    #    ],
    save_dir = save_dir,
    )
# Out:
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 43.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 44.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
x = 'dateIdentified'
y = 'database'
hue = 'language'
style='availability'

plot(x=x, y=y, hue=hue, style=style, data=df,
    type='scatter',
    split={hue:4,style:3,y:7}, #slice_top={y:5},
    legend_position='out',
    drop_doubles=[key_id],
    xlabel='date', ylabel='database',
    sort_alpha=[hue],
    save_dir = save_dir,
    )

# %%
x = 'dateIdentified'
hue = 'database'

plot(x=x, hue=hue, data=df,
    type='dist',
    split={hue:5},
    legend_position=None, drop_na=[hue],
    drop_doubles=[key_id],
    xlabel='date', ylabel='', huelabel='database',
    save_dir = save_dir,
    #1998
    )

# %%
hue = 'language'

plot(hue=hue, data=df,
    type='perc',
    drop_doubles=[key_id], drop_na=[hue],
    legend_position='out',
    save_dir = save_dir,
    )

# %%
hue = 'database'
x='PDF'

plot(hue=hue, data=df,
    type='perc',
    split={hue:7},
    drop_doubles=[key_id], drop_na=[hue],
    legend_position='out',
    save_dir = save_dir,
    )

# %%
x = 'dateIdentified'
hue = 'PDF'
y = 'language'
palette = sns.color_palette('tab10',n_colors=10)

plot(x=x, y=y, hue=hue, data=df,
    type='violin',
    legend_position='lower left',
    slice_top={y:3},
    drop_doubles=[key_id], drop_na=[x],
    xlabel='date', ylabel='language', huelabel='pdf availability',
    #vlines=[
    #    {'x':1950,'ymin':0,'ymax':1,'gid':'copyright', 'c':palette[3]},
    #    {'x':2020,'ymin':0,'ymax':1,'gid':'last publication', 'c':'black'}
    #    ],
    swarm=True,
    save_dir = save_dir,
    )
# German: copyright from 1950
# English: a lot of info in unvailable documents
# Out:
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/elubrini/GitHub/psylve/venv/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 16.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
x = 'dateIdentified'
hue = 'availability'
y = 'language'

plot(x=x, y=y, hue=hue, data=df,
    type='violin',
    legend_position='lower left',
    split={hue:2,y:2}, 
    xlabel='date', ylabel='language', huelabel='online availability',
    save_dir = save_dir,
    )
